# %%
import os
import csv
from lib.crawler_noCmt import fetch_posts, fetch_content_only
import pandas as pd
import time
os.makedirs('./data', exist_ok=True)

BOARDS = {
    '마법사':    (2295, None),
    '궁수':      (2296, None),
    '도적':      (2297, None),
    '전사':      (2294, None),
    '해적':      (2298, None),
    '자유':      (5974, None),
    '자유_30추': (5974, 'chuchu'),
    '자유_10추': (5974, 'chu'),
}

POSTS_CSV = './data/posts.csv'

def load_collected_post_ids():
    if not os.path.exists(POSTS_CSV):
        return set()
    try:
        df = pd.read_csv(POSTS_CSV, dtype=str)
        return set(df['번호'].astype(str))
    except Exception:
        return set()

def crawl_all(max_pages_per_board=5):
    post_fields = ['게시판','번호','제목','링크','본문']
    collected_post_ids = load_collected_post_ids()
    post_file_exists = os.path.exists(POSTS_CSV)

    # 각 게시판별로 현재 순회중인 페이지번호 저장
    current_pages = {board: 51 for board in BOARDS.keys()}
    finished = set()

    with open(POSTS_CSV, 'a', newline='', encoding='utf-8-sig') as pf:
        pw = csv.DictWriter(pf, fieldnames=post_fields)
        if not post_file_exists:
            pw.writeheader()

        while len(finished) < len(BOARDS):
            for board_name, (bid, flt) in BOARDS.items():
                if board_name in finished:
                    continue
                page_start = current_pages[board_name]
                page_end = page_start + max_pages_per_board - 1
                empty_page_hit = False
                for page in range(page_start, page_end + 1):
                    posts = fetch_posts(bid, page, flt)
                    if not posts:
                        finished.add(board_name)
                        empty_page_hit = True
                        break
                    print(f'[{board_name}] 페이지 {page} → {len(posts)}건')
                    for post in posts:
                        if post['번호'] in collected_post_ids:
                            continue
                        try:
                            content = fetch_content_only(post['링크'])
                        except Exception as e:
                            print(f"[ERROR] fetch_content_only 실패: {post['링크']} → {e}")
                            content = ''
                        pw.writerow({'게시판': board_name, '번호': post['번호'], '제목': post['제목'], '링크': post['링크'], '본문': content})
                        collected_post_ids.add(post['번호'])
                        time.sleep(2)
                if not empty_page_hit:
                    current_pages[board_name] += max_pages_per_board

    print('크롤링 완료 → data/posts.csv')

if __name__ == '__main__':
    crawl_all(max_pages_per_board=5)
# Out:
# [마법사] 페이지 51 → 40건
# [마법사] 페이지 52 → 40건
# [마법사] 페이지 53 → 40건
# [마법사] 페이지 54 → 40건
# [마법사] 페이지 55 → 40건
# [궁수] 페이지 51 → 40건
# [궁수] 페이지 52 → 40건
# [궁수] 페이지 53 → 40건
# [궁수] 페이지 54 → 40건
# [궁수] 페이지 55 → 40건
# [도적] 페이지 51 → 40건
# [도적] 페이지 52 → 40건
# [도적] 페이지 53 → 40건
# [도적] 페이지 54 → 40건
# [도적] 페이지 55 → 40건
# [전사] 페이지 51 → 40건
# [전사] 페이지 52 → 40건
# [전사] 페이지 53 → 40건
# [전사] 페이지 54 → 40건
# [전사] 페이지 55 → 40건
# [해적] 페이지 51 → 40건
# [해적] 페이지 52 → 40건
# [해적] 페이지 53 → 40건
# [해적] 페이지 54 → 40건
# [해적] 페이지 55 → 40건
# [자유] 페이지 51 → 70건
# [자유] 페이지 52 → 70건
# [자유] 페이지 53 → 70건
# [자유] 페이지 54 → 70건
# [자유] 페이지 55 → 70건
# [자유_30추] 페이지 51 → 70건
# [자유_30추] 페이지 52 → 70건
# [자유_30추] 페이지 53 → 70건
# [자유_30추] 페이지 54 → 70건
# [자유_30추] 페이지 55 → 70건
# [자유_10추] 페이지 51 → 70건
# [자유_10추] 페이지 52 → 70건
# [자유_10추] 페이지 53 → 70건
# [자유_10추] 페이지 54 → 70건
# [자유_10추] 페이지 55 → 70건
# [마법사] 페이지 56 → 40건
# [마법사] 페이지 57 → 40건
# [마법사] 페이지 58 → 40건
# [마법사] 페이지 59 → 40건
# [마법사] 페이지 60 → 40건
# [궁수] 페이지 56 → 40건
# [궁수] 페이지 57 → 40건
# [궁수] 페이지 58 → 40건
# [궁수] 페이지 59 → 40건
# [궁수] 페이지 60 → 40건
# [도적] 페이지 56 → 40건
# [도적] 페이지 57 → 40건
# [도적] 페이지 58 → 40건
# [도적] 페이지 59 → 40건
# [도적] 페이지 60 → 40건
# [전사] 페이지 56 → 40건
# [전사] 페이지 57 → 40건
# [전사] 페이지 58 → 40건
# [전사] 페이지 59 → 40건
# [전사] 페이지 60 → 40건
# [해적] 페이지 56 → 40건
# [해적] 페이지 57 → 40건
# [해적] 페이지 58 → 40건
# [해적] 페이지 59 → 40건
# [해적] 페이지 60 → 40건
# [자유] 페이지 56 → 70건
# [자유] 페이지 57 → 70건
# [자유] 페이지 58 → 70건
# [자유] 페이지 59 → 70건
# [자유] 페이지 60 → 70건
# [자유_30추] 페이지 56 → 70건
# [자유_30추] 페이지 57 → 70건
# [자유_30추] 페이지 58 → 70건
# [자유_30추] 페이지 59 → 70건
# [자유_30추] 페이지 60 → 70건
# [자유_10추] 페이지 56 → 70건
# [자유_10추] 페이지 57 → 70건
# [자유_10추] 페이지 58 → 70건
# [자유_10추] 페이지 59 → 70건
# [자유_10추] 페이지 60 → 70건
# [마법사] 페이지 61 → 40건
# [마법사] 페이지 62 → 40건
# [마법사] 페이지 63 → 40건
# [마법사] 페이지 64 → 40건
# [마법사] 페이지 65 → 40건
# [궁수] 페이지 61 → 40건
# [궁수] 페이지 62 → 40건
# [궁수] 페이지 63 → 40건
# [궁수] 페이지 64 → 40건
# [궁수] 페이지 65 → 40건
# [도적] 페이지 61 → 40건
# [도적] 페이지 62 → 40건
# [도적] 페이지 63 → 40건
# [도적] 페이지 64 → 40건
# [도적] 페이지 65 → 40건
# [전사] 페이지 61 → 40건
# [전사] 페이지 62 → 40건
# [전사] 페이지 63 → 40건
# [전사] 페이지 64 → 40건
# [전사] 페이지 65 → 40건
# [해적] 페이지 61 → 40건
# [해적] 페이지 62 → 40건
# [해적] 페이지 63 → 40건
# [해적] 페이지 64 → 40건
# [해적] 페이지 65 → 40건
# [자유] 페이지 61 → 70건
# [자유] 페이지 62 → 70건
# [자유] 페이지 63 → 70건
# [자유] 페이지 64 → 70건
# [자유] 페이지 65 → 70건
# [자유_30추] 페이지 61 → 70건
# [자유_30추] 페이지 62 → 70건
# [자유_30추] 페이지 63 → 70건
# [자유_30추] 페이지 64 → 70건
# [자유_30추] 페이지 65 → 70건
# [자유_10추] 페이지 61 → 70건
# [자유_10추] 페이지 62 → 70건
# [자유_10추] 페이지 63 → 70건
# [자유_10추] 페이지 64 → 70건
# [자유_10추] 페이지 65 → 70건
# [마법사] 페이지 66 → 40건
# [마법사] 페이지 67 → 40건
# [마법사] 페이지 68 → 40건
# [마법사] 페이지 69 → 40건
# [마법사] 페이지 70 → 40건
# [궁수] 페이지 66 → 40건
# [궁수] 페이지 67 → 40건
# [궁수] 페이지 68 → 40건
# [궁수] 페이지 69 → 40건
# [궁수] 페이지 70 → 40건
# [도적] 페이지 66 → 40건
# [도적] 페이지 67 → 40건
# [도적] 페이지 68 → 40건
# [도적] 페이지 69 → 40건
# [도적] 페이지 70 → 40건
# [전사] 페이지 66 → 40건
# [전사] 페이지 67 → 40건
# [전사] 페이지 68 → 40건
# [전사] 페이지 69 → 40건
# [전사] 페이지 70 → 40건
# [해적] 페이지 66 → 40건
# [해적] 페이지 67 → 40건
# [해적] 페이지 68 → 40건
# [해적] 페이지 69 → 40건
# [해적] 페이지 70 → 40건
# [자유] 페이지 66 → 70건
# [자유] 페이지 67 → 70건
# [자유] 페이지 68 → 70건
# [자유] 페이지 69 → 70건
# [자유] 페이지 70 → 70건
# [자유_30추] 페이지 66 → 70건
# [자유_30추] 페이지 67 → 70건
# [자유_30추] 페이지 68 → 70건
# [자유_30추] 페이지 69 → 70건
# [자유_30추] 페이지 70 → 70건
# [자유_10추] 페이지 66 → 70건
# [자유_10추] 페이지 67 → 70건
# [자유_10추] 페이지 68 → 70건
# [자유_10추] 페이지 69 → 70건
# [자유_10추] 페이지 70 → 70건
# [마법사] 페이지 71 → 40건
# [마법사] 페이지 72 → 40건
# [마법사] 페이지 73 → 40건
# [마법사] 페이지 74 → 40건
# [마법사] 페이지 75 → 40건
# [궁수] 페이지 71 → 40건
# [궁수] 페이지 72 → 40건
# [궁수] 페이지 73 → 40건
# [궁수] 페이지 74 → 40건
# [궁수] 페이지 75 → 40건
# [도적] 페이지 71 → 40건
# [도적] 페이지 72 → 40건
# [도적] 페이지 73 → 40건
# [도적] 페이지 74 → 40건
# [도적] 페이지 75 → 40건
# [전사] 페이지 71 → 40건
# [전사] 페이지 72 → 40건
# [전사] 페이지 73 → 40건
# [전사] 페이지 74 → 40건
# [전사] 페이지 75 → 40건
# [해적] 페이지 71 → 40건
# [해적] 페이지 72 → 40건
# [해적] 페이지 73 → 40건
# [해적] 페이지 74 → 40건
# [해적] 페이지 75 → 40건
# [자유] 페이지 71 → 70건
# [자유] 페이지 72 → 70건
# [자유] 페이지 73 → 70건
# [자유] 페이지 74 → 70건
# [자유] 페이지 75 → 70건
# [자유_30추] 페이지 71 → 70건
# [자유_30추] 페이지 72 → 70건
# [자유_30추] 페이지 73 → 70건
# [자유_30추] 페이지 74 → 70건
# [자유_30추] 페이지 75 → 70건
# [자유_10추] 페이지 71 → 70건
# [자유_10추] 페이지 72 → 70건
# [자유_10추] 페이지 73 → 70건
# [자유_10추] 페이지 74 → 70건
# [자유_10추] 페이지 75 → 70건
# [마법사] 페이지 76 → 40건
# [마법사] 페이지 77 → 40건
# [마법사] 페이지 78 → 40건
# [마법사] 페이지 79 → 40건
# [마법사] 페이지 80 → 40건
# [궁수] 페이지 76 → 40건
# [궁수] 페이지 77 → 40건
# [궁수] 페이지 78 → 40건
# [궁수] 페이지 79 → 40건
# [궁수] 페이지 80 → 40건
# [도적] 페이지 76 → 40건
# [도적] 페이지 77 → 40건
# [도적] 페이지 78 → 40건
# [도적] 페이지 79 → 40건
# [도적] 페이지 80 → 40건
# [전사] 페이지 76 → 40건
# [전사] 페이지 77 → 40건
# [전사] 페이지 78 → 40건
# [전사] 페이지 79 → 40건
# [전사] 페이지 80 → 40건
# [해적] 페이지 76 → 40건
# [해적] 페이지 77 → 40건
# [해적] 페이지 78 → 40건
# [해적] 페이지 79 → 40건
# [해적] 페이지 80 → 40건
# [자유] 페이지 76 → 70건
# [자유] 페이지 77 → 70건
# [자유] 페이지 78 → 70건
# [자유] 페이지 79 → 70건
# [자유] 페이지 80 → 70건
# [자유_30추] 페이지 76 → 70건
# [자유_30추] 페이지 77 → 70건
# [자유_30추] 페이지 78 → 70건
# [자유_30추] 페이지 79 → 70건
# [자유_30추] 페이지 80 → 70건
# [자유_10추] 페이지 76 → 70건
# [자유_10추] 페이지 77 → 70건
# [자유_10추] 페이지 78 → 70건
# [자유_10추] 페이지 79 → 70건
# [자유_10추] 페이지 80 → 70건
# [마법사] 페이지 81 → 40건
# [마법사] 페이지 82 → 40건
# [마법사] 페이지 83 → 40건
# [마법사] 페이지 84 → 40건
# [마법사] 페이지 85 → 40건
# [궁수] 페이지 81 → 40건
# [궁수] 페이지 82 → 40건
# [궁수] 페이지 83 → 40건
# [궁수] 페이지 84 → 40건
# [궁수] 페이지 85 → 40건
# [도적] 페이지 81 → 40건
# [도적] 페이지 82 → 40건
# [도적] 페이지 83 → 40건
# [도적] 페이지 84 → 40건
# [도적] 페이지 85 → 40건
# [전사] 페이지 81 → 40건
# [전사] 페이지 82 → 40건
# [전사] 페이지 83 → 40건
# [전사] 페이지 84 → 40건
# [전사] 페이지 85 → 40건
# [해적] 페이지 81 → 40건
# [해적] 페이지 82 → 40건
# [해적] 페이지 83 → 40건
# [해적] 페이지 84 → 40건
# [해적] 페이지 85 → 40건
# [자유] 페이지 81 → 70건
# [자유] 페이지 82 → 70건
# [자유] 페이지 83 → 70건
# [자유] 페이지 84 → 70건
# [자유] 페이지 85 → 70건
# [자유_30추] 페이지 81 → 70건
# [자유_30추] 페이지 82 → 70건
# [자유_30추] 페이지 83 → 70건
# [자유_30추] 페이지 84 → 70건
# [자유_30추] 페이지 85 → 70건
# [자유_10추] 페이지 81 → 70건
# [자유_10추] 페이지 82 → 70건
# [자유_10추] 페이지 83 → 70건
# [자유_10추] 페이지 84 → 70건
# [자유_10추] 페이지 85 → 70건
# [마법사] 페이지 86 → 40건
# [마법사] 페이지 87 → 40건
# [마법사] 페이지 88 → 40건
# [마법사] 페이지 89 → 40건
# [마법사] 페이지 90 → 40건
# [궁수] 페이지 86 → 40건
# [궁수] 페이지 87 → 40건
# [궁수] 페이지 88 → 40건
# [궁수] 페이지 89 → 40건
# [궁수] 페이지 90 → 40건
# [도적] 페이지 86 → 40건
# [도적] 페이지 87 → 40건
# [도적] 페이지 88 → 40건
# [도적] 페이지 89 → 40건
# [도적] 페이지 90 → 40건
# [전사] 페이지 86 → 40건
# [전사] 페이지 87 → 40건
# [전사] 페이지 88 → 40건
# [전사] 페이지 89 → 40건
# [전사] 페이지 90 → 40건
# [해적] 페이지 86 → 40건
# [해적] 페이지 87 → 40건
# [해적] 페이지 88 → 40건
# [해적] 페이지 89 → 40건
# [해적] 페이지 90 → 40건
# [자유] 페이지 86 → 70건
# [자유] 페이지 87 → 70건
# [자유] 페이지 88 → 70건
# [자유] 페이지 89 → 70건
# [자유] 페이지 90 → 70건
# [자유_30추] 페이지 86 → 70건
# [자유_30추] 페이지 87 → 70건
# [자유_30추] 페이지 88 → 70건
# [자유_30추] 페이지 89 → 70건
# [자유_30추] 페이지 90 → 70건
# [자유_10추] 페이지 86 → 70건
# [자유_10추] 페이지 87 → 70건
# [자유_10추] 페이지 88 → 70건
# [자유_10추] 페이지 89 → 70건
# [자유_10추] 페이지 90 → 70건
# [마법사] 페이지 91 → 40건
# [마법사] 페이지 92 → 40건
# [마법사] 페이지 93 → 40건
# [마법사] 페이지 94 → 40건
# [마법사] 페이지 95 → 40건
# [궁수] 페이지 91 → 40건
# [궁수] 페이지 92 → 40건
# [궁수] 페이지 93 → 40건
# [궁수] 페이지 94 → 40건
# [궁수] 페이지 95 → 40건
# [도적] 페이지 91 → 40건
# [도적] 페이지 92 → 40건
# [도적] 페이지 93 → 40건
# [도적] 페이지 94 → 40건
# [도적] 페이지 95 → 40건
# [전사] 페이지 91 → 40건
# [전사] 페이지 92 → 40건
# [전사] 페이지 93 → 40건
# [전사] 페이지 94 → 40건
# [전사] 페이지 95 → 40건
# [해적] 페이지 91 → 40건
# [해적] 페이지 92 → 40건
# [해적] 페이지 93 → 40건
# [해적] 페이지 94 → 40건
# [해적] 페이지 95 → 40건
# [자유] 페이지 91 → 70건
# [자유] 페이지 92 → 70건
# [자유] 페이지 93 → 70건
# [자유] 페이지 94 → 70건
# [자유] 페이지 95 → 70건
# [자유_30추] 페이지 91 → 70건
# [자유_30추] 페이지 92 → 70건
# [자유_30추] 페이지 93 → 70건
# [자유_30추] 페이지 94 → 70건
# [자유_30추] 페이지 95 → 70건
# [자유_10추] 페이지 91 → 70건
# [자유_10추] 페이지 92 → 70건
# [자유_10추] 페이지 93 → 70건
# [자유_10추] 페이지 94 → 70건
# [자유_10추] 페이지 95 → 70건
# [마법사] 페이지 96 → 40건
# [마법사] 페이지 97 → 40건
# [마법사] 페이지 98 → 40건
# [마법사] 페이지 99 → 40건
# [마법사] 페이지 100 → 40건
# [궁수] 페이지 96 → 40건
# [궁수] 페이지 97 → 40건
# [궁수] 페이지 98 → 40건
# [궁수] 페이지 99 → 40건
# [궁수] 페이지 100 → 40건
# [도적] 페이지 96 → 40건
# [도적] 페이지 97 → 40건
# [도적] 페이지 98 → 40건
# [도적] 페이지 99 → 40건
# [도적] 페이지 100 → 40건
# [전사] 페이지 96 → 40건
# [전사] 페이지 97 → 40건
# [전사] 페이지 98 → 40건
# [전사] 페이지 99 → 40건
# [전사] 페이지 100 → 40건
# [해적] 페이지 96 → 40건
# [해적] 페이지 97 → 40건
# [해적] 페이지 98 → 40건
# [해적] 페이지 99 → 40건
# [해적] 페이지 100 → 40건
# [자유] 페이지 96 → 70건
# [자유] 페이지 97 → 70건
# [자유] 페이지 98 → 70건
# [자유] 페이지 99 → 70건
# [자유] 페이지 100 → 70건
# [자유_30추] 페이지 96 → 70건
# [자유_30추] 페이지 97 → 70건
# [자유_30추] 페이지 98 → 70건
# [자유_30추] 페이지 99 → 70건
# [자유_30추] 페이지 100 → 70건
# [자유_10추] 페이지 96 → 70건
# [자유_10추] 페이지 97 → 70건
# [자유_10추] 페이지 98 → 70건
# [자유_10추] 페이지 99 → 70건
# [자유_10추] 페이지 100 → 70건
# [마법사] 페이지 101 → 40건
# [마법사] 페이지 102 → 40건
# [마법사] 페이지 103 → 40건
# [마법사] 페이지 104 → 40건
# [마법사] 페이지 105 → 40건
# [궁수] 페이지 101 → 40건
# [궁수] 페이지 102 → 40건
# [궁수] 페이지 103 → 40건
# [궁수] 페이지 104 → 40건
# [궁수] 페이지 105 → 40건
# [도적] 페이지 101 → 40건
# [도적] 페이지 102 → 40건
# [도적] 페이지 103 → 40건
# [도적] 페이지 104 → 40건
# [도적] 페이지 105 → 40건
# [전사] 페이지 101 → 40건
# [전사] 페이지 102 → 40건
# [전사] 페이지 103 → 40건
# [전사] 페이지 104 → 40건
# [전사] 페이지 105 → 40건
# [해적] 페이지 101 → 40건
# [해적] 페이지 102 → 40건
# [해적] 페이지 103 → 40건
# [해적] 페이지 104 → 40건
# [해적] 페이지 105 → 40건
# [자유] 페이지 101 → 70건
# [자유] 페이지 102 → 70건
# [자유] 페이지 103 → 70건
# [자유] 페이지 104 → 70건
# [자유] 페이지 105 → 70건
# [자유_30추] 페이지 101 → 70건
# [자유_30추] 페이지 102 → 70건
# [자유_30추] 페이지 103 → 70건
# [자유_30추] 페이지 104 → 70건
# [자유_30추] 페이지 105 → 70건
# [자유_10추] 페이지 101 → 70건
# [자유_10추] 페이지 102 → 70건
# [자유_10추] 페이지 103 → 70건
# [자유_10추] 페이지 104 → 70건
# [자유_10추] 페이지 105 → 70건
# [마법사] 페이지 106 → 40건
# [마법사] 페이지 107 → 40건
# [마법사] 페이지 108 → 40건
# [마법사] 페이지 109 → 40건
# [마법사] 페이지 110 → 40건
# [궁수] 페이지 106 → 40건
# [궁수] 페이지 107 → 40건
# [궁수] 페이지 108 → 40건
# [궁수] 페이지 109 → 40건
# [궁수] 페이지 110 → 40건
# [도적] 페이지 106 → 40건
# [도적] 페이지 107 → 40건
# [도적] 페이지 108 → 40건
# [도적] 페이지 109 → 40건
# [도적] 페이지 110 → 40건
# [전사] 페이지 106 → 40건
# [전사] 페이지 107 → 40건
# [전사] 페이지 108 → 40건
# [전사] 페이지 109 → 40건
# [전사] 페이지 110 → 40건
# [해적] 페이지 106 → 40건
# [해적] 페이지 107 → 40건
# [해적] 페이지 108 → 40건
# [해적] 페이지 109 → 40건
# [해적] 페이지 110 → 40건
# [자유] 페이지 106 → 70건
# [자유] 페이지 107 → 70건
# [자유] 페이지 108 → 70건
# [자유] 페이지 109 → 70건
# [자유] 페이지 110 → 70건
# [자유_30추] 페이지 106 → 70건
# [자유_30추] 페이지 107 → 70건
# [자유_30추] 페이지 108 → 70건
# [자유_30추] 페이지 109 → 70건
# [자유_30추] 페이지 110 → 70건
# [자유_10추] 페이지 106 → 70건
# [자유_10추] 페이지 107 → 70건
# [자유_10추] 페이지 108 → 70건
# [자유_10추] 페이지 109 → 70건
# [자유_10추] 페이지 110 → 70건
# [마법사] 페이지 111 → 40건
# [마법사] 페이지 112 → 40건
# [마법사] 페이지 113 → 40건
# [마법사] 페이지 114 → 40건
# [마법사] 페이지 115 → 40건
# [궁수] 페이지 111 → 40건
# [궁수] 페이지 112 → 40건
# [궁수] 페이지 113 → 40건
# [궁수] 페이지 114 → 40건
# [궁수] 페이지 115 → 40건
# [도적] 페이지 111 → 40건
# [도적] 페이지 112 → 40건
# [도적] 페이지 113 → 40건
# [도적] 페이지 114 → 40건
# [도적] 페이지 115 → 40건
# [전사] 페이지 111 → 40건
# [전사] 페이지 112 → 40건
# [전사] 페이지 113 → 40건
# [전사] 페이지 114 → 40건
# [전사] 페이지 115 → 40건
# [해적] 페이지 111 → 40건
# [해적] 페이지 112 → 40건
# [해적] 페이지 113 → 40건
# [해적] 페이지 114 → 40건
# [해적] 페이지 115 → 40건
# [자유] 페이지 111 → 70건
# [자유] 페이지 112 → 70건
# [자유] 페이지 113 → 70건
# [자유] 페이지 114 → 70건
# [자유] 페이지 115 → 70건
# [자유_30추] 페이지 111 → 70건
# [자유_30추] 페이지 112 → 70건
# [자유_30추] 페이지 113 → 70건
# [자유_30추] 페이지 114 → 70건
# [자유_30추] 페이지 115 → 70건
# [자유_10추] 페이지 111 → 70건
# [자유_10추] 페이지 112 → 70건
# [자유_10추] 페이지 113 → 70건
# [자유_10추] 페이지 114 → 70건
# [자유_10추] 페이지 115 → 70건
# [마법사] 페이지 116 → 40건
# [마법사] 페이지 117 → 40건
# [마법사] 페이지 118 → 40건
# [마법사] 페이지 119 → 40건
# [마법사] 페이지 120 → 40건
# [궁수] 페이지 116 → 40건
# [궁수] 페이지 117 → 40건
# [궁수] 페이지 118 → 40건
# [궁수] 페이지 119 → 40건
# [궁수] 페이지 120 → 40건
# [도적] 페이지 116 → 40건
# [도적] 페이지 117 → 40건
# [도적] 페이지 118 → 40건
# [도적] 페이지 119 → 40건
# [도적] 페이지 120 → 40건
# [전사] 페이지 116 → 40건
# [전사] 페이지 117 → 40건
# [전사] 페이지 118 → 40건
# [전사] 페이지 119 → 40건
# [전사] 페이지 120 → 40건
# [해적] 페이지 116 → 40건
# [해적] 페이지 117 → 40건
# [해적] 페이지 118 → 40건
# [해적] 페이지 119 → 40건
# [해적] 페이지 120 → 40건
# [자유] 페이지 116 → 70건
# [자유] 페이지 117 → 70건
# [자유] 페이지 118 → 70건
# [자유] 페이지 119 → 70건
# [자유] 페이지 120 → 70건
# [자유_30추] 페이지 116 → 70건
# [자유_30추] 페이지 117 → 70건
# [자유_30추] 페이지 118 → 70건
# [자유_30추] 페이지 119 → 70건
# [자유_30추] 페이지 120 → 70건
# [자유_10추] 페이지 116 → 70건
# [자유_10추] 페이지 117 → 70건
# [자유_10추] 페이지 118 → 70건
# [자유_10추] 페이지 119 → 70건
# [자유_10추] 페이지 120 → 70건
# [마법사] 페이지 121 → 40건
# [마법사] 페이지 122 → 40건
# [마법사] 페이지 123 → 40건
# [마법사] 페이지 124 → 40건
# [마법사] 페이지 125 → 40건
# [궁수] 페이지 121 → 40건
# [궁수] 페이지 122 → 40건
# [궁수] 페이지 123 → 40건
# [궁수] 페이지 124 → 40건
# [궁수] 페이지 125 → 40건
# [도적] 페이지 121 → 40건
# [도적] 페이지 122 → 40건
# [도적] 페이지 123 → 40건
# [도적] 페이지 124 → 40건
# [도적] 페이지 125 → 40건
# [전사] 페이지 121 → 40건
# [전사] 페이지 122 → 40건
# [전사] 페이지 123 → 40건
# [전사] 페이지 124 → 40건
# [전사] 페이지 125 → 40건
# [해적] 페이지 121 → 40건
# [해적] 페이지 122 → 40건
# [해적] 페이지 123 → 40건
# [해적] 페이지 124 → 40건
# [해적] 페이지 125 → 40건
# [자유] 페이지 121 → 70건
# [자유] 페이지 122 → 70건
# [자유] 페이지 123 → 70건
# [자유] 페이지 124 → 70건
# [자유] 페이지 125 → 70건
# [자유_30추] 페이지 121 → 70건
# [자유_30추] 페이지 122 → 70건
# [자유_30추] 페이지 123 → 70건
# [자유_30추] 페이지 124 → 70건
# [자유_30추] 페이지 125 → 70건
# [자유_10추] 페이지 121 → 70건
# [자유_10추] 페이지 122 → 70건
# [자유_10추] 페이지 123 → 70건
# [자유_10추] 페이지 124 → 70건
# [자유_10추] 페이지 125 → 70건
# [마법사] 페이지 126 → 40건
# [마법사] 페이지 127 → 40건
# [마법사] 페이지 128 → 40건
# [마법사] 페이지 129 → 40건
# [마법사] 페이지 130 → 40건
# [궁수] 페이지 126 → 40건
# [궁수] 페이지 127 → 40건
# [궁수] 페이지 128 → 40건
# [궁수] 페이지 129 → 40건
# [궁수] 페이지 130 → 40건
# [도적] 페이지 126 → 40건
# [도적] 페이지 127 → 40건
# [도적] 페이지 128 → 40건
# [도적] 페이지 129 → 40건
# [도적] 페이지 130 → 40건
# [전사] 페이지 126 → 40건
# [전사] 페이지 127 → 40건
# [전사] 페이지 128 → 40건
# [전사] 페이지 129 → 40건
# [전사] 페이지 130 → 40건
# [해적] 페이지 126 → 40건
# [해적] 페이지 127 → 40건
# [해적] 페이지 128 → 40건
# [해적] 페이지 129 → 40건
# [해적] 페이지 130 → 40건
# [자유] 페이지 126 → 70건
# [자유] 페이지 127 → 70건
# [자유] 페이지 128 → 70건
# [자유] 페이지 129 → 70건
# [자유] 페이지 130 → 70건
# [자유_30추] 페이지 126 → 70건
# [자유_30추] 페이지 127 → 70건
# [자유_30추] 페이지 128 → 70건
# [자유_30추] 페이지 129 → 70건
# [자유_30추] 페이지 130 → 70건
# [자유_10추] 페이지 126 → 70건
# [자유_10추] 페이지 127 → 70건
# [자유_10추] 페이지 128 → 70건
# [자유_10추] 페이지 129 → 70건
# [자유_10추] 페이지 130 → 70건
# [마법사] 페이지 131 → 40건
# [마법사] 페이지 132 → 40건
# [마법사] 페이지 133 → 40건
# [마법사] 페이지 134 → 40건
# [마법사] 페이지 135 → 40건
# [궁수] 페이지 131 → 40건
# [궁수] 페이지 132 → 40건
# [궁수] 페이지 133 → 40건
# [궁수] 페이지 134 → 40건
# [궁수] 페이지 135 → 40건
# [도적] 페이지 131 → 40건
# [도적] 페이지 132 → 40건
# [도적] 페이지 133 → 40건
# [도적] 페이지 134 → 40건
# [도적] 페이지 135 → 40건
# [전사] 페이지 131 → 40건
# [전사] 페이지 132 → 40건
# [전사] 페이지 133 → 40건
# [전사] 페이지 134 → 40건
# [전사] 페이지 135 → 40건
# [해적] 페이지 131 → 40건
# [해적] 페이지 132 → 40건
# [해적] 페이지 133 → 40건
# [해적] 페이지 134 → 40건
# [해적] 페이지 135 → 40건
# [자유] 페이지 131 → 70건
# [자유] 페이지 132 → 70건
# [자유] 페이지 133 → 70건
# [자유] 페이지 134 → 70건
# [자유] 페이지 135 → 70건
# [자유_30추] 페이지 131 → 70건
# [자유_30추] 페이지 132 → 70건
# [자유_30추] 페이지 133 → 70건
# [자유_30추] 페이지 134 → 70건
# [자유_30추] 페이지 135 → 70건
# [자유_10추] 페이지 131 → 70건
# [자유_10추] 페이지 132 → 70건
# [자유_10추] 페이지 133 → 70건
# [자유_10추] 페이지 134 → 70건
# [자유_10추] 페이지 135 → 70건
# [마법사] 페이지 136 → 40건
# [마법사] 페이지 137 → 40건
# [마법사] 페이지 138 → 40건
# [마법사] 페이지 139 → 40건
# [마법사] 페이지 140 → 40건
# [궁수] 페이지 136 → 40건
# [궁수] 페이지 137 → 40건
# [궁수] 페이지 138 → 40건
# [궁수] 페이지 139 → 40건
# [궁수] 페이지 140 → 40건
# [도적] 페이지 136 → 40건
# [도적] 페이지 137 → 40건
# [도적] 페이지 138 → 40건
# [도적] 페이지 139 → 40건
# [도적] 페이지 140 → 40건
# [전사] 페이지 136 → 40건
# [전사] 페이지 137 → 40건
# [전사] 페이지 138 → 40건
# [전사] 페이지 139 → 40건
# [전사] 페이지 140 → 40건
# [해적] 페이지 136 → 40건
# [해적] 페이지 137 → 40건
# [해적] 페이지 138 → 40건
# [해적] 페이지 139 → 40건
# [해적] 페이지 140 → 40건
# [자유] 페이지 136 → 70건
# [자유] 페이지 137 → 70건
# [자유] 페이지 138 → 70건
# [자유] 페이지 139 → 70건
# [자유] 페이지 140 → 70건
# [자유_30추] 페이지 136 → 70건
# [자유_30추] 페이지 137 → 70건
# [자유_30추] 페이지 138 → 70건
# [자유_30추] 페이지 139 → 70건
# [자유_30추] 페이지 140 → 70건
# [자유_10추] 페이지 136 → 70건
# [자유_10추] 페이지 137 → 70건
# [자유_10추] 페이지 138 → 70건
# [자유_10추] 페이지 139 → 70건
# [자유_10추] 페이지 140 → 70건
# [마법사] 페이지 141 → 40건
# [마법사] 페이지 142 → 40건
# [마법사] 페이지 143 → 40건
# [마법사] 페이지 144 → 40건
# [마법사] 페이지 145 → 40건
# [궁수] 페이지 141 → 40건
# [궁수] 페이지 142 → 40건
# [궁수] 페이지 143 → 40건
# [궁수] 페이지 144 → 40건
# [궁수] 페이지 145 → 40건
# [도적] 페이지 141 → 40건
# [도적] 페이지 142 → 40건
# [도적] 페이지 143 → 40건
# [도적] 페이지 144 → 40건
# [도적] 페이지 145 → 40건
# [전사] 페이지 141 → 40건
# [전사] 페이지 142 → 40건
# [전사] 페이지 143 → 40건
# [전사] 페이지 144 → 40건
# [전사] 페이지 145 → 40건
# [해적] 페이지 141 → 40건
# [해적] 페이지 142 → 40건
# [해적] 페이지 143 → 40건
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 75
#      72     print('크롤링 완료 → data/posts.csv')
#      74 if __name__ == '__main__':
# ---> 75     crawl_all(max_pages_per_board=5)
#
# Cell In[1], line 68, in crawl_all(max_pages_per_board)
#      66         pw.writerow({'게시판': board_name, '번호': post['번호'], '제목': post['제목'], '링크': post['링크'], '본문': content})
#      67         collected_post_ids.add(post['번호'])
# ---> 68         time.sleep(2)
#      69 if not empty_page_hit:
#      70     current_pages[board_name] += max_pages_per_board
#
# KeyboardInterrupt:
